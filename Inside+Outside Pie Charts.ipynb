# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

path = "TotalData2.csv"
df = pd.read_csv(path)

# %%
df2 = df.loc[lambda df: df['Inside/Outside'] == df['Inside/Outside']]

df2 = df2.replace('Outisde', 'Outside') #there was an error in my original binning- misspelled

# %%
#there were 553,698,898 crimes reported and we have 42,061,536 

winter_crimes = df2.loc[df2['Season'] == 'Winter']
spring_crimes = df2.loc[df2['Season'] == 'Spring']
summer_crimes = df2.loc[df2['Season'] == 'Summer']
fall_crimes = df2.loc[df2['Season'] == 'Fall']

w1 = winter_crimes.loc[winter_crimes['Inside/Outside'] == 'Inside']['ID'].count()
w2 = winter_crimes.loc[winter_crimes['Inside/Outside'] == 'Outside']['ID'].count()
sp1 = spring_crimes.loc[spring_crimes['Inside/Outside'] == 'Inside']['ID'].count()
sp2 = spring_crimes.loc[spring_crimes['Inside/Outside'] == 'Outside']['ID'].count()
su1 = summer_crimes.loc[summer_crimes['Inside/Outside'] == 'Inside']['ID'].count()
su2 = summer_crimes.loc[summer_crimes['Inside/Outside'] == 'Outside']['ID'].count()
f1 = fall_crimes.loc[fall_crimes['Inside/Outside'] == 'Inside']['ID'].count()
f2 = fall_crimes.loc[fall_crimes['Inside/Outside'] == 'Outside']['ID'].count()

# %%
labels = ['Inside', 'Outside']
sizes = [w1, w2]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in Winter")
plt.axis('equal')

plt.savefig('piecharts/winterpie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [sp1, sp2]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in Spring")
plt.axis('equal')

plt.savefig('piecharts/springpie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [su1, su2]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in Summer")
plt.axis('equal')

plt.savefig('piecharts/summerpie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [f1, f2]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in Fall")
plt.axis('equal')

plt.savefig('piecharts/fallpie.png')

# %%
c0 = df2.loc[df2['Weather'] == 'Below freezing']
c30 = df2.loc[df2['Weather'] == '30-50 degrees']
c50 = df2.loc[df2['Weather'] == '50-70 degrees']
c70 = df2.loc[df2['Weather'] == '70-90 degrees']
c90 = df2.loc[df2['Weather'] == 'Over 90 degrees']

c0i = c0.loc[c0['Inside/Outside'] == 'Inside']['ID'].count()
c0o = c0.loc[c0['Inside/Outside'] == 'Outside']['ID'].count()

c30i = c30.loc[c30['Inside/Outside'] == 'Inside']['ID'].count()
c30o = c30.loc[c30['Inside/Outside'] == 'Outside']['ID'].count()

c50i = c50.loc[c50['Inside/Outside'] == 'Inside']['ID'].count()
c50o = c50.loc[c50['Inside/Outside'] == 'Outside']['ID'].count()

c70i = c70.loc[c70['Inside/Outside'] == 'Inside']['ID'].count()
c70o = c70.loc[c70['Inside/Outside'] == 'Outside']['ID'].count()

c90i = c90.loc[c90['Inside/Outside'] == 'Inside']['ID'].count()
c90o = c90.loc[c90['Inside/Outside'] == 'Outside']['ID'].count()

# %%
labels = ['Inside', 'Outside']
sizes = [c0i, c0o]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in below-freezing weather")
plt.axis('equal')

plt.savefig('piecharts/freezingpie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [c30i, c30o]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in 30-50° F weather")
plt.axis('equal')

plt.savefig('piecharts/30-50pie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [c50i, c50o]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in 50-70° F weather")
plt.axis('equal')

plt.savefig('piecharts/50-70pie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [c70i, c70o]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in 70-90° F weather")
plt.axis('equal')

plt.savefig('piecharts/70-90pie.png')

# %%
labels = ['Inside', 'Outside']
sizes = [c90i, c90o]
explode = (0, 0.1)
fig1 = plt.pie(list(sizes),labels=labels, explode=explode,autopct='%1.2f%%',
       shadow=True, startangle=90)
plt.title("Crimes reported in 90°+")
plt.axis('equal')

plt.savefig('piecharts/90pie.png')
